# %% [markdown]
# # Startup

# %%
import nfltools.loader as loader
from nfltools.settings import ROOT_DIR
ROOT_DIR
# Out:
# '/home/maxo/code/nfl-tools'

# %%
loader.preload([2023])
# Out:
# 2023 done.

# %%
pbp = loader.get_play_by_play(2023)
# Out:
# 2023 done.
# Downcasting floats.
